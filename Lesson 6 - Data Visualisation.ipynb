# %% [markdown]
# # Data Visualization with Python
#
# ## Introduction
# In this notebook, we will delve into various data visualisation techniques using Python. We will explore line graphs, growth types, trends, scatter plots, correlation and causation, identifying outliers, bar plots, frequency tables, histograms, types of distribution, and box plots. Each section includes explanations and corresponding Python code.

# %%
## 1. Importing Libraries

#Let's start by importing the necessary libraries.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Line Graphs
#
# ### What are Line Graphs?
# Line graphs are used to display data points connected by lines, often to visualise changes over time.

# %%
# Creating a sample dataset
years = np.arange(2010, 2021)
sales = np.array([100, 120, 140, 360, 180, 200, 220, 240, 260, 280, 300])

# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(years, sales, marker='o', linestyle='-', color='b')
plt.title('Sales Over Years mod')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
import pandas as pd
who_time_series = pd.read_csv('Datasets/WHO_time_series.csv')
print(who_time_series.head())
# Out:
#   Date_reported Country  New_cases  Cumulative_cases  New_deaths  \
# 0    2020-01-04   China          1                 1           0
# 1    2020-01-05   China          0                 1           0
# 2    2020-01-06   China          3                 4           0
# 3    2020-01-07   China          0                 4           0
# 4    2020-01-08   China          0                 4           0
#
#    Cumulative_deaths
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %% [markdown]
# ## Types of Growth
# ### Linear, Cumulative, and Exponential Growth
# We will visualise different types of growth using line graphs.

# %%
poland = who_time_series[who_time_series['Country'] == 'Poland']

plt.plot(poland['Date_reported'], poland['Cumulative_cases'])
plt.title('Poland: Linear Growth')
plt.xlabel('Date')
plt.ylabel('Number Of Cases')
plt.show()

# %%
italy = who_time_series[who_time_series['Country'] == 'Italy']

plt.plot(italy['Date_reported'], italy['Cumulative_cases'])
plt.title('Italy: Cumulative Growth')
plt.xlabel('Date')
plt.ylabel('Number Of Cases')
plt.show()

# %%
india = who_time_series[who_time_series['Country'] == 'India']

plt.plot(india['Date_reported'], india['Cumulative_cases'])
plt.title('India: Exponential Growth')
plt.xlabel('Date')
plt.ylabel('Number Of Cases')
plt.show()

# %%
belarus = who_time_series[who_time_series['Country'] == 'Belarus']

plt.plot(belarus['Date_reported'], belarus['New_cases'])
plt.title('Belarus: New Reported Cases')
plt.xlabel('Date')
plt.ylabel('Number Of Cases')
plt.show()

# %% [markdown]
# ## Comparing Graphs
# ### Comparing Multiple Line Graphs
# We can compare multiple datasets using line graphs on the same axes.

# %%
france = who_time_series[who_time_series['Country'] == 'France']
uk = who_time_series[who_time_series['Country'] == 'The United Kingdom']

plt.plot(france['Date_reported'], france['Cumulative_cases'],
         label='France')
plt.plot(uk['Date_reported'], uk['Cumulative_cases'],
         label='The UK')
plt.xticks(  np.arange(0, len(uk['Date_reported']), 50))
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

bike_sharing = pd.read_csv('day.csv')
bike_sharing['dteday'] = pd.to_datetime(bike_sharing['dteday'])

# %% [markdown]
# ## Trends in Data
# ### Identifying Trends: Seasonal, Cyclical, and Random
# Trends help in understanding underlying patterns in time series data.

# %%
# Creating a time series dataset with seasonal and random trends
np.random.seed(42)
dates = pd.date_range(start='2020-01-01', periods=365)
sales = np.sin(np.linspace(0, 3 * np.pi, 365)) * 100 + np.random.normal(0, 10, 365) + 200

plt.figure(figsize=(12, 6))
plt.plot(dates, sales, label='Sales')
plt.title('Seasonal Trends in Sales')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Scatter Plots
# ### Introduction to Scatter Plots
# Scatter plots are used to visualize the relationship between two numerical variables.

# %%
# Generating random data
np.random.seed(0)
x = np.random.rand(100)
y = x * 3 + np.random.normal(0, 0.1, 100)

plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='g')
plt.title('Scatter Plot of X vs Y')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# ## Correlation and Causation
# ### Understanding Correlation
# Correlation measures the strength and direction of the relationship between two variables.

# %%
# Enhanced synthetic data to show clearer trends
np.random.seed(42)
data_size = 100

# Time variable affecting both variables similarly
time = np.linspace(1, 12, data_size)

# Ice cream sales - higher variance to make the trend clearer
ice_cream_sales = 50 + 2.5 * time + np.random.normal(0, 20, data_size)

# Sunglasses sales - directly correlated with time and similar trend
sunglasses_sales = 30 + 2.5 * time + np.random.normal(0, 20, data_size)

# Generating trend lines
ice_cream_trend = np.poly1d(np.polyfit(time, ice_cream_sales, 1))(time)
sunglasses_trend = np.poly1d(np.polyfit(time, sunglasses_sales, 1))(time)

plt.figure(figsize=(12, 8))
plt.scatter(time, ice_cream_sales, color='purple', alpha=0.6, label='Ice Cream Sales')
plt.plot(time, ice_cream_trend, "r--", label='Trend: Ice Cream Sales')
plt.scatter(time, sunglasses_sales, color='orange', alpha=0.6, label='Sunglasses Sales')
plt.plot(time, sunglasses_trend, "b--", label='Trend: Sunglasses Sales')
plt.title('Clear Trends Showing Correlation Without Causation')
plt.xlabel('Time (Months)')
plt.ylabel('Sales')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Finding Outliers
# ### Identifying Outliers in Data
# Outliers are data points that differ significantly from other observations.

# %%
# Adding outliers to the dataset
x_with_outliers = np.append(x, [0.1, 0.2])
y_with_outliers = np.append(y, [3, 5])

plt.figure(figsize=(10, 6))
plt.scatter(x_with_outliers, y_with_outliers, color='r')
plt.title('Scatter Plot with Outliers')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# ## Bar Plots
# ### Introduction to Bar Plots
# Bar plots are used to compare the frequency or magnitude of different categories.

# %%
# Creating a sample dataset
categories = ['Category A', 'Category B', 'Category C']
values = [25, 35, 30]

plt.figure(figsize=(10, 6))
plt.bar(categories, values, color='orange')
plt.title('Bar Plot of Categories')
plt.xlabel('Category')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# ## Frequency Tables and Histograms
# ### Frequency Tables
# Frequency tables summarize the distribution of a categorical variable.

# %%
# Creating a frequency table
data = pd.Series(['A', 'B', 'A', 'C', 'B', 'A', 'B', 'C', 'C', 'C'])
frequency_table = data.value_counts()

print("Frequency Table:\n", frequency_table)
# Out:
# Frequency Table:
#  C    4
# A    3
# B    3
# Name: count, dtype: int64

# %% [markdown]
# ### Histograms
# Histograms visualize the distribution of a continuous variable by dividing data into bins.

# %%
# Generating random data and plotting a histogram
data = np.random.randn(1000)

plt.figure(figsize=(10, 6))
plt.hist(data, bins=30, color='purple', alpha=0.7)
plt.title('Histogram of Normally Distributed Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Types of Distribution
# ### Normal, Skewed, and Uniform Distributions
# Different types of distributions indicate how data points are spread.

# %%
# Normal Distribution
normal_data = np.random.normal(0, 1, 1000)

# Skewed Distribution
skewed_data = np.random.exponential(1, 1000)

# Uniform Distribution
uniform_data = np.random.uniform(-3, 3, 1000)

plt.figure(figsize=(14, 8))

plt.subplot(3, 1, 1)
plt.hist(normal_data, bins=30, color='blue', alpha=0.7)
plt.title('Normal Distribution')

plt.subplot(3, 1, 2)
plt.hist(skewed_data, bins=30, color='green', alpha=0.7)
plt.title('Skewed Distribution')

plt.subplot(3, 1, 3)
plt.hist(uniform_data, bins=30, color='red', alpha=0.7)
plt.title('Uniform Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Challenge

# %% [markdown]
# ### From: Dr. Emily Carter, Director
# ### Subject: Required Data Analysis on Shark Attacks
#
# As part of our ongoing research into shark behaviour and public safety, I am requesting a detailed analysis of shark attack data from our existing dataset. This will help guide our discussions at the upcoming international marine safety council meeting.
#
# Please prepare the following analyses:
#
# 1. **Shark Attacks by Decade**: Construct a bar graph detailing the frequency of shark attacks sorted by decade.
# 2. **Top 10 Countries by Number of Shark Attacks**: Generate a bar chart that lists the top ten countries where shark attacks have been most frequent.
# 3. **Distribution of Shark Attack Types**: Create a histogram chart that shows the distribution of various types of shark attacks such as provoked, unprovoked, etc.
# 4. **Shark Attacks by Gender**: Develop a bar graph that compares the number of shark attacks by gender.
# 5. **Monthly Distribution of Shark Attacks**: Produce a line graph that displays the monthly frequency of shark attacks to identify any seasonal patterns.
#
# ## Presentation of Findings:
#
# Your findings will be compiled into a report with each of the requested graphs and a brief discussion on the potential implications of these trends on public safety and shark conservation efforts. The clarity and depth of your analysis are imperative as they will contribute directly to our upcoming policy review discussions.
#
# Please ensure all graphs are clearly labelled with appropriate titles, axes labels, and legends where applicable. The report should be comprehensive yet concise, ready for presentation to a diverse group of stakeholders.
#
# Thank you for your prompt attention to this request.
#
# Best Regards,
#
# Dr. Emily Carter
# Director, Marine Research Institute
#
# <p>-----------------------------------------
# For this use the dataset `attacks.csv`
# -----------------------------------------</p>
